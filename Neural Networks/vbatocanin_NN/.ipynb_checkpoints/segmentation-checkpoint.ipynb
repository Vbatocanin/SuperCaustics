# %%
# !pip install torch torchvision matplotlib tqdm pillow
# Out:
# Requirement already satisfied: torch in d:\dev\supercaustics\.venv-new\lib\site-packages (2.3.1)
# Requirement already satisfied: torchvision in d:\dev\supercaustics\.venv-new\lib\site-packages (0.18.1)
# Requirement already satisfied: matplotlib in d:\dev\supercaustics\.venv-new\lib\site-packages (3.9.0)
# Requirement already satisfied: tqdm in d:\dev\supercaustics\.venv-new\lib\site-packages (4.66.4)
# Requirement already satisfied: pillow in d:\dev\supercaustics\.venv-new\lib\site-packages (10.3.0)
# Requirement already satisfied: filelock in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in d:\dev\supercaustics\.venv-new\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: numpy in d:\dev\supercaustics\.venv-new\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\dev\supercaustics\.venv-new\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in d:\dev\supercaustics\.venv-new\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in d:\dev\supercaustics\.venv-new\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in d:\dev\supercaustics\.venv-new\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: six>=1.5 in d:\dev\supercaustics\.venv-new\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\dev\supercaustics\.venv-new\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in d:\dev\supercaustics\.venv-new\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt

# %%
image_dir = '../Data/Picture_Caustic'
mask_dir = '../Data/Caustic_Seg'

image_files = os.listdir(image_dir)
mask_files = os.listdir(mask_dir)

# Validate that each image has a corresponding mask
valid_pairs = [(img, img) for img in image_files if img in mask_files]

print(f"Found {len(valid_pairs)} valid image-mask pairs out of {len(image_files)} images.")
# Out:
# Found 1066 valid image-mask pairs out of 1066 images.

# %%
class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        
        # Load images and masks into a dictionary
        self.data_dict = self._load_data()
        self.images = list(self.data_dict.keys())

    def _load_data(self):
        data_dict = {}
        image_files = os.listdir(self.image_dir)
        mask_files = os.listdir(self.mask_dir)
        
        for img_name in image_files:
            img_path = os.path.join(self.image_dir, img_name)
            mask_path = os.path.join(self.mask_dir, img_name)
            
            if os.path.exists(mask_path):
                image = Image.open(img_path).convert("RGB")
                mask = Image.open(mask_path).convert("L")
                data_dict[img_name] = (image, mask)
        
        return data_dict

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        image, mask = self.data_dict[img_name]
        
        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

dataset = SegmentationDataset(image_dir, mask_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
import matplotlib.pyplot as plt

def show_sample_images(dataset, num_samples=4):
    fig, ax = plt.subplots(num_samples, 2, figsize=(10, 10))
    for i in range(num_samples):
        img, mask = dataset[i]
        
        ax[i, 0].imshow(img.permute(1, 2, 0))
        ax[i, 0].axis('off')
        
        ax[i, 1].imshow(mask.squeeze(), cmap='gray')
        ax[i, 1].axis('off')
    
    plt.subplots_adjust(wspace=0.01, hspace=0.01)
    plt.show()

show_sample_images(dataset)

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

# %%
class DownSampleLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Down, self).__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)

# %%
class UpSampleLayer(nn.Module):
    def __init__(self, in_channels, out_channels, bilinear=True):
        super(Up, self).__init__()
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            self.up = nn.ConvTranspose2d(in_channels // 2, in_channels // 2, kernel_size=2, stride=2)

        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]
        x1 = nn.functional.pad(x1, [diffX // 2, diffX - diffX // 2, diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

# %%
class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

# %%
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.inc = DoubleConv(n_channels, 64)
        self.down1 = DownSampleLayer(64, 128)
        self.down2 = DownSampleLayer(128, 256)
        self.down3 = DownSampleLayer(256, 512)
        self.down4 = DownSampleLayer(512, 512)
        self.up1 = UpSampleLayer(1024, 256)
        self.up2 = UpSampleLayer(512, 128)
        self.up3 = UpSampleLayer(256, 64)
        self.up4 = UpSampleLayer(128, 64)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = UNet(n_channels=3, n_classes=1).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training Loop with Logging and Progress Bar
def train_model(model, criterion, optimizer, dataloader, num_epochs=25):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        progress_bar = tqdm(dataloader, desc=f'Epoch {epoch+1}/{num_epochs}')
        for inputs, masks in progress_bar:
            inputs = inputs.to(device)
            masks = masks.to(device)
            
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * inputs.size(0)
            progress_bar.set_postfix(loss=loss.item())
        
        epoch_loss = running_loss / len(dataloader.dataset)
        logging.info(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}')

# %%
train_model(model, criterion, optimizer, dataloader, num_epochs=25)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_model(model, criterion, optimizer, dataloader, num_epochs=25)
#
# Cell In[11], line 5, in train_model(model, criterion, optimizer, dataloader, num_epochs)
#       3 model.train()
#       4 running_loss = 0.0
# ----> 5 for inputs, masks in dataloader:
#       6     inputs = inputs.to(device)
#       7     masks = masks.to(device)
#
# File D:\Dev\SuperCaustics\.venv-new\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File D:\Dev\SuperCaustics\.venv-new\Lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\Dev\SuperCaustics\.venv-new\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[4], line 14, in SegmentationDataset.__getitem__(self, idx)
#      12 img_path = os.path.join(self.image_dir, self.images[idx])
#      13 mask_path = os.path.join(self.mask_dir, self.images[idx])
# ---> 14 image = Image.open(img_path).convert("RGB")
#      15 mask = Image.open(mask_path).convert("L")
#      17 if self.transform:
#
# File D:\Dev\SuperCaustics\.venv-new\Lib\site-packages\PIL\Image.py:941, in Image.convert(self, mode, matrix, dither, palette, colors)
#     889 def convert(
#     890     self,
#     891     mode: str | None = None,
#    (...)
#     895     colors: int = 256,
#     896 ) -> Image:
#     897     """
#     898     Returns a converted copy of this image. For the "P" mode, this
#     899     method translates pixels through the palette.  If mode is
#    (...)
#     938     :returns: An :py:class:`~PIL.Image.Image` object.
#     939     """
# --> 941     self.load()
#     943     has_transparency = "transparency" in self.info
#     944     if not mode and self.mode == "P":
#     945         # determine default mode
#
# File D:\Dev\SuperCaustics\.venv-new\Lib\site-packages\PIL\ImageFile.py:291, in ImageFile.load(self)
#     288         raise OSError(msg)
#     290 b = b + s
# --> 291 n, err_code = decoder.decode(b)
#     292 if n < 0:
#     293     break
#
# KeyboardInterrupt:
